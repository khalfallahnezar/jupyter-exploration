# %% [markdown]
# # My First Notebook
#
# My first markdown cell in Jupyter.
#
# This notebook was created for the **Intro to Jupyter and GitHub** lab (ITAI2373). It demonstrates a Markdown cell and a Code cell.
#
# ## Markdown basics
# - `#` makes a heading
# - `*italic*` makes *italic* text
# - `**bold**` makes **bold** text

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# A little more Python to show the code cell working
name = "Nezar"
for i in range(3):
    print(f"{name} is learning Jupyter! (line {i+1})")
# Out:
# Nezar is learning Jupyter! (line 1)
# Nezar is learning Jupyter! (line 2)
# Nezar is learning Jupyter! (line 3)
